# %% [markdown]
# # Ch8. 모듈과 활용

# %%
import datetime
datetime.datetime.now()

today=datetime.date.today()
print(today)

today.month
# Out:
# 2026-05-03
# 5

# %%
dir(datetime)
start_time=datetime.datetime.now()
start_time.replace(month=12, day=25)
# Out:
# datetime.datetime(2026, 12, 25, 12, 19, 5, 515512)

# %%
from datetime import datetime
start_time=datetime.now()
start_time.replace(month=12,day=25)
# Out:
# datetime.datetime(2026, 12, 25, 14, 23, 9, 409885)

# %% [markdown]
# ## lab 8-1

# %%
from datetime import datetime as dt
print(dt,"년",date,"월",today,"일")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from datetime import datetime as dt
# ----> 2 print(dt,"년",date,"월",today,"일")
#
# NameError: name 'date' is not defined

# %%
from datetime import datetime

now = datetime.now()

# 오전/오후 판별
if now.hour >= 12:
    ampm = "오후"
    hour = now.hour - 12
else:
    ampm = "오전"
    hour = now.hour

print(f"오늘의 날짜: {now.year}년 {now.month}월 {now.day}일")
print(f"현재시간: {ampm} {hour}시 {now.minute}분 {now.second}초")
# Out:
# 오늘의 날짜: 2026년 5월 3일
# 현재시간: 오후 2시 46분 13초

# %% [markdown]
# ## lab 8-2

# %%
from datetime import datetime

now = datetime.now()

# 오전/오후 판별
if now.hour >= 12:
    ampm = "오후"
    hour = now.hour - 12
else:
    ampm = "오전"
    hour = now.hour

nowtime=datetime.now()
christmas= datetime(2027, 12, 25)
gap= christmas-nowtime
days=gap.days
hours=gap.seconds//3600

print(f"오늘은 {now.year}년 {now.month}월 {now.day}일입니다")
print(f"2027년 크리스마스 까지는  {days}일 {hours }시간 남았습니다")
# Out:
# 오늘은 2026년 5월 3일입니다
# 2027년 크리스마스 까지는  600일 8시간 남았습니다

# %%
from datetime import datetime

now = datetime.now()

# 오전/오후 판별
if now.hour >= 12:
    ampm = "오후"
    hour = now.hour - 12
else:
    ampm = "오전"
    hour = now.hour

nowtime=datetime.now()
christmas= datetime(2027, 12, 25)
gap= christmas-nowtime
days=gap.days
hours=gap.seconds//3600

print(f"오늘은 {now.year}년 {now.month}월 {now.day}일입니다")
print(f"2027년 크리스마스 까지는  {days}일 {hours }시간 남았습니다")

# %%
from datetime import datetime
now = datetime.now()

if now.hour>=12:
    ampm = "오후"
    hour = now.hour -12
else:
    ampm="오전"
    hour=now.hour


now=datetime.now()
mybirth= datetime(2027,01,19)
